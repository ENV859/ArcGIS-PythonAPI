# %% [markdown]
# # An introduction to geocoding
#
# Geocoders are tools to which you pass in an address / place of interest and it gives back the coordinates of that place.
#
# The **`arcgis.geocoding`** module provides types and functions for geocoding, batch geocoding and reverse geocoding.

# %%
from arcgis.gis import GIS
from arcgis import geocoding
from getpass import getpass
password = getpass()
# Out:
# ········

# %%
gis = GIS("http://www.arcgis.com", "arcgis_python", password)

# %% [markdown]
# ## Geocoding addresses
# All geocoding operations are handled by `geocode()` function. It can geocode
#
#  1. single line address
#  2. multi field address
#  3. points of interest
#  4. administrative place names
#  5. postal codes

# %%
results = geocoding.geocode('San Diego, CA')
results
# Out:
# [{'address': 'San Diego, California',
#   'location': {'x': -117.16170999999997, 'y': 32.71568000000008},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego, California',
#    'LongLabel': 'San Diego, CA, USA',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'Locality',
#    'Type': 'City',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Diego, California',
#    'Phone': '',
#    'URL': '',
#    'Rank': 2,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'San Diego Metro Area',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.16170999999997,
#    'Y': 32.71568000000008,
#    'DisplayX': -117.16170999999997,
#    'DisplayY': 32.71568000000008,
#    'Xmin': -117.40070999999998,
#    'Xmax': -116.92270999999997,
#    'Ymin': 32.47668000000008,
#    'Ymax': 32.954680000000074,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.40070999999998,
#    'ymin': 32.47668000000008,
#    'xmax': -116.92270999999997,
#    'ymax': 32.954680000000074}},
#  {'address': 'San Diego, Carabobo',
#   'location': {'x': -67.95480999999995, 'y': 10.257310000000075},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego, Carabobo',
#    'LongLabel': 'San Diego, Carabobo, VEN',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'Locality',
#    'Type': 'City',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'Carabobo',
#    'Phone': '',
#    'URL': '',
#    'Rank': 8.51,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': '',
#    'MetroArea': '',
#    'Subregion': 'San Diego',
#    'Region': 'Carabobo',
#    'RegionAbbr': '',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'VEN',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -67.95480999999995,
#    'Y': 10.257310000000075,
#    'DisplayX': -67.95480999999995,
#    'DisplayY': 10.257310000000075,
#    'Xmin': -68.02080999999995,
#    'Xmax': -67.88880999999995,
#    'Ymin': 10.191310000000074,
#    'Ymax': 10.323310000000076,
#    'ExInfo': ''},
#   'extent': {'xmin': -68.02080999999995,
#    'ymin': 10.191310000000074,
#    'xmax': -67.88880999999995,
#    'ymax': 10.323310000000076}},
#  {'address': 'San-Diego',
#   'location': {'x': -117.19743999999997, 'y': 32.732350000000054},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San-Diego',
#    'LongLabel': 'San-Diego, San Diego, CA, USA',
#    'ShortLabel': 'San-Diego',
#    'Addr_type': 'POI',
#    'Type': 'Airport',
#    'PlaceName': 'San-Diego',
#    'Place_addr': 'San Diego, California',
#    'Phone': '',
#    'URL': '',
#    'Rank': 9,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': '',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.19743999999997,
#    'Y': 32.732350000000054,
#    'DisplayX': -117.19743999999997,
#    'DisplayY': 32.732350000000054,
#    'Xmin': -117.22243999999998,
#    'Xmax': -117.17243999999997,
#    'Ymin': 32.707350000000055,
#    'Ymax': 32.75735000000005,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.22243999999998,
#    'ymin': 32.707350000000055,
#    'xmax': -117.17243999999997,
#    'ymax': 32.75735000000005}},
#  {'address': 'San-Diego, San Diego, California',
#   'location': {'x': -117.15725999999995, 'y': 32.71533000000005},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San-Diego, San Diego, California',
#    'LongLabel': 'San-Diego, San Diego, CA, USA',
#    'ShortLabel': 'San-Diego',
#    'Addr_type': 'Locality',
#    'Type': 'City',
#    'PlaceName': 'San-Diego',
#    'Place_addr': 'San Diego, California',
#    'Phone': '',
#    'URL': '',
#    'Rank': 10,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': '',
#    'Subregion': 'San Diego',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.15725999999995,
#    'Y': 32.71533000000005,
#    'DisplayX': -117.15725999999995,
#    'DisplayY': 32.71533000000005,
#    'Xmin': -117.39525999999995,
#    'Xmax': -116.91925999999995,
#    'Ymin': 32.47733000000005,
#    'Ymax': 32.95333000000005,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.39525999999995,
#    'ymin': 32.47733000000005,
#    'xmax': -116.91925999999995,
#    'ymax': 32.95333000000005}},
#  {'address': 'San Diego, San Roque, Cádiz, Andalucía',
#   'location': {'x': -5.256909999999948, 'y': 36.31313000000006},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego, San Roque, Cádiz, Andalucía',
#    'LongLabel': 'San Diego, San Roque, Cádiz, Andalucía, ESP',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'Locality',
#    'Type': 'Village',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Roque, Cádiz, Andalucía',
#    'Phone': '',
#    'URL': '',
#    'Rank': 15,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': 'San Diego',
#    'District': '',
#    'City': 'San Roque',
#    'MetroArea': '',
#    'Subregion': 'Cádiz',
#    'Region': 'Andalucía',
#    'RegionAbbr': '',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'ESP',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -5.256909999999948,
#    'Y': 36.31313000000006,
#    'DisplayX': -5.256909999999948,
#    'DisplayY': 36.31313000000006,
#    'Xmin': -5.266909999999948,
#    'Xmax': -5.246909999999948,
#    'Ymin': 36.30313000000006,
#    'Ymax': 36.323130000000056,
#    'ExInfo': ''},
#   'extent': {'xmin': -5.266909999999948,
#    'ymin': 36.30313000000006,
#    'xmax': -5.246909999999948,
#    'ymax': 36.323130000000056}},
#  {'address': 'San Diego County, California',
#   'location': {'x': -116.756412437, 'y': 33.03389977000006},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego County, California',
#    'LongLabel': 'San Diego County, CA, USA',
#    'ShortLabel': 'San Diego County',
#    'Addr_type': 'Locality',
#    'Type': 'County',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'California',
#    'Phone': '',
#    'URL': '',
#    'Rank': 17.1,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': '',
#    'MetroArea': '',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -116.756412437,
#    'Y': 33.03389977000006,
#    'DisplayX': -116.756412437,
#    'DisplayY': 33.03389977000006,
#    'Xmin': -117.63041243699999,
#    'Xmax': -115.882412437,
#    'Ymin': 32.15989977000006,
#    'Ymax': 33.907899770000064,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.63041243699999,
#    'ymin': 32.15989977000006,
#    'xmax': -115.882412437,
#    'ymax': 33.907899770000064}},
#  {'address': 'San Diego',
#   'location': {'x': -67.96346999999997, 'y': 10.208500000000072},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego',
#    'LongLabel': 'San Diego, Valencia, San Diego, Carabobo, VEN',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'POI',
#    'Type': 'Grocery',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Diego, Valencia, San Diego, Carabobo',
#    'Phone': '',
#    'URL': '',
#    'Rank': 19,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Subregion': 'San Diego',
#    'Region': 'Carabobo',
#    'RegionAbbr': '',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'VEN',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -67.96346999999997,
#    'Y': 10.208500000000072,
#    'DisplayX': -67.96346999999997,
#    'DisplayY': 10.208500000000072,
#    'Xmin': -67.96846999999997,
#    'Xmax': -67.95846999999998,
#    'Ymin': 10.203500000000071,
#    'Ymax': 10.213500000000073,
#    'ExInfo': ''},
#   'extent': {'xmin': -67.96846999999997,
#    'ymin': 10.203500000000071,
#    'xmax': -67.95846999999998,
#    'ymax': 10.213500000000073}},
#  {'address': 'San Diego',
#   'location': {'x': -67.96510999999998, 'y': 10.221920000000068},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego',
#    'LongLabel': 'San Diego, Valencia, San Diego, Carabobo, VEN',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'POI',
#    'Type': 'Grocery',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Diego, Valencia, San Diego, Carabobo',
#    'Phone': '',
#    'URL': '',
#    'Rank': 19,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Subregion': 'San Diego',
#    'Region': 'Carabobo',
#    'RegionAbbr': '',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'VEN',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -67.96510999999998,
#    'Y': 10.221920000000068,
#    'DisplayX': -67.96510999999998,
#    'DisplayY': 10.221920000000068,
#    'Xmin': -67.97010999999998,
#    'Xmax': -67.96010999999999,
#    'Ymin': 10.216920000000068,
#    'Ymax': 10.226920000000069,
#    'ExInfo': ''},
#   'extent': {'xmin': -67.97010999999998,
#    'ymin': 10.216920000000068,
#    'xmax': -67.96010999999999,
#    'ymax': 10.226920000000069}},
#  {'address': 'San Diego',
#   'location': {'x': -67.96510999999998, 'y': 10.221920000000068},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego',
#    'LongLabel': 'San Diego, Valencia, San Diego, Carabobo, VEN',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'POI',
#    'Type': 'Pharmacy',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Diego, Valencia, San Diego, Carabobo',
#    'Phone': '',
#    'URL': '',
#    'Rank': 19,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Subregion': 'San Diego',
#    'Region': 'Carabobo',
#    'RegionAbbr': '',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'VEN',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -67.96510999999998,
#    'Y': 10.221920000000068,
#    'DisplayX': -67.96510999999998,
#    'DisplayY': 10.221920000000068,
#    'Xmin': -67.97010999999998,
#    'Xmax': -67.96010999999999,
#    'Ymin': 10.216920000000068,
#    'Ymax': 10.226920000000069,
#    'ExInfo': ''},
#   'extent': {'xmin': -67.97010999999998,
#    'ymin': 10.216920000000068,
#    'xmax': -67.96010999999999,
#    'ymax': 10.226920000000069}},
#  {'address': 'San Diego',
#   'location': {'x': -67.96511999999996, 'y': 10.222920000000045},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego',
#    'LongLabel': 'San Diego, Valencia, San Diego, Carabobo, VEN',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'POI',
#    'Type': 'Shopping Center',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Diego, Valencia, San Diego, Carabobo',
#    'Phone': '',
#    'URL': '',
#    'Rank': 19,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Subregion': 'San Diego',
#    'Region': 'Carabobo',
#    'RegionAbbr': '',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'VEN',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -67.96511999999996,
#    'Y': 10.222920000000045,
#    'DisplayX': -67.96511999999996,
#    'DisplayY': 10.222920000000045,
#    'Xmin': -67.97011999999995,
#    'Xmax': -67.96011999999996,
#    'Ymin': 10.217920000000044,
#    'Ymax': 10.227920000000045,
#    'ExInfo': ''},
#   'extent': {'xmin': -67.97011999999995,
#    'ymin': 10.217920000000044,
#    'xmax': -67.96011999999996,
#    'ymax': 10.227920000000045}},
#  {'address': 'San Diego',
#   'location': {'x': -67.96749999999997, 'y': 10.194800000000043},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego',
#    'LongLabel': 'San Diego, Calle 102, San Diego, Valencia, San Diego, Carabobo, VEN',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'POI',
#    'Type': 'Hotel',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'Calle 102, San Diego, Valencia, San Diego, Carabobo',
#    'Phone': '',
#    'URL': '',
#    'Rank': 19,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': 'Calle',
#    'StName': '102',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'Calle 102',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Subregion': 'San Diego',
#    'Region': 'Carabobo',
#    'RegionAbbr': '',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'VEN',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -67.96749999999997,
#    'Y': 10.194800000000043,
#    'DisplayX': -67.96749999999997,
#    'DisplayY': 10.194800000000043,
#    'Xmin': -67.97249999999997,
#    'Xmax': -67.96249999999998,
#    'Ymin': 10.189800000000043,
#    'Ymax': 10.199800000000044,
#    'ExInfo': ''},
#   'extent': {'xmin': -67.97249999999997,
#    'ymin': 10.189800000000043,
#    'xmax': -67.96249999999998,
#    'ymax': 10.199800000000044}},
#  {'address': 'San Diego',
#   'location': {'x': -67.95372999999995, 'y': 10.256020000000035},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'San Diego',
#    'LongLabel': 'San Diego, Avenida Sucre, San Diego, Valencia, San Diego, Carabobo, VEN',
#    'ShortLabel': 'San Diego',
#    'Addr_type': 'POI',
#    'Type': 'Church',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'Avenida Sucre, San Diego, Valencia, San Diego, Carabobo',
#    'Phone': '',
#    'URL': '',
#    'Rank': 19,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': 'Avenida',
#    'StName': 'Sucre',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'Avenida Sucre',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Subregion': 'San Diego',
#    'Region': 'Carabobo',
#    'RegionAbbr': '',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'VEN',
#    'LangCode': 'SPA',
#    'Distance': 0,
#    'X': -67.95372999999995,
#    'Y': 10.256020000000035,
#    'DisplayX': -67.95372999999995,
#    'DisplayY': 10.256020000000035,
#    'Xmin': -67.95872999999995,
#    'Xmax': -67.94872999999995,
#    'Ymin': 10.251020000000034,
#    'Ymax': 10.261020000000036,
#    'ExInfo': ''},
#   'extent': {'xmin': -67.95872999999995,
#    'ymin': 10.251020000000034,
#    'xmax': -67.94872999999995,
#    'ymax': 10.261020000000036}},
#  {'address': 'California St, San Diego, California, 92101',
#   'location': {'x': -117.17192415209873, 'y': 32.727582353261575},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'California St, San Diego, California, 92101',
#    'LongLabel': 'California St, San Diego, CA, 92101, USA',
#    'ShortLabel': 'California St',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'California St, San Diego, California, 92101',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'California',
#    'StType': 'St',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'California St',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': 'Midway District',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'San Diego Metro Area',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '92101',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.17192415209873,
#    'Y': 32.727582353261575,
#    'DisplayX': -117.17192415209873,
#    'DisplayY': 32.727582353261575,
#    'Xmin': -117.17292415209873,
#    'Xmax': -117.17092415209872,
#    'Ymin': 32.72658235326158,
#    'Ymax': 32.72858235326157,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.17292415209873,
#    'ymin': 32.72658235326158,
#    'xmax': -117.17092415209872,
#    'ymax': 32.72858235326157}},
#  {'address': 'California St, San Diego, California, 92101',
#   'location': {'x': -117.1806891927498, 'y': 32.74010843605822},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'California St, San Diego, California, 92101',
#    'LongLabel': 'California St, San Diego, CA, 92101, USA',
#    'ShortLabel': 'California St',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'California St, San Diego, California, 92101',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'California',
#    'StType': 'St',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'California St',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': 'Middletown',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'San Diego Metro Area',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '92101',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.1806891927498,
#    'Y': 32.74010843605822,
#    'DisplayX': -117.1806891927498,
#    'DisplayY': 32.74010843605822,
#    'Xmin': -117.1816891927498,
#    'Xmax': -117.17968919274979,
#    'Ymin': 32.739108436058224,
#    'Ymax': 32.74110843605822,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.1816891927498,
#    'ymin': 32.739108436058224,
#    'xmax': -117.17968919274979,
#    'ymax': 32.74110843605822}},
#  {'address': 'California St, San Diego, California, 92110',
#   'location': {'x': -117.18497305344265, 'y': 32.744990510932766},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'California St, San Diego, California, 92110',
#    'LongLabel': 'California St, San Diego, CA, 92110, USA',
#    'ShortLabel': 'California St',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'California St, San Diego, California, 92110',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'California',
#    'StType': 'St',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'California St',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': 'Mission Hills',
#    'District': '',
#    'City': 'San Diego',
#    'MetroArea': 'San Diego Metro Area',
#    'Subregion': 'San Diego County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '92110',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.18497305344265,
#    'Y': 32.744990510932766,
#    'DisplayX': -117.18497305344265,
#    'DisplayY': 32.744990510932766,
#    'Xmin': -117.18597305344265,
#    'Xmax': -117.18397305344264,
#    'Ymin': 32.74399051093277,
#    'Ymax': 32.745990510932764,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.18597305344265,
#    'ymin': 32.74399051093277,
#    'xmax': -117.18397305344264,
#    'ymax': 32.745990510932764}},
#  {'address': 'San Diego Dr, Yucca Valley, California, 92284',
#   'location': {'x': -116.4017370684428, 'y': 34.09238110683216},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'San Diego Dr, Yucca Valley, California, 92284',
#    'LongLabel': 'San Diego Dr, Yucca Valley, CA, 92284, USA',
#    'ShortLabel': 'San Diego Dr',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'San Diego Dr, Yucca Valley, California, 92284',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'San Diego',
#    'StType': 'Dr',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'San Diego Dr',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Yucca Valley',
#    'MetroArea': '',
#    'Subregion': 'San Bernardino County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '92284',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -116.4017370684428,
#    'Y': 34.09238110683216,
#    'DisplayX': -116.4017370684428,
#    'DisplayY': 34.09238110683216,
#    'Xmin': -116.4027370684428,
#    'Xmax': -116.4007370684428,
#    'Ymin': 34.09138110683216,
#    'Ymax': 34.093381106832155,
#    'ExInfo': ''},
#   'extent': {'xmin': -116.4027370684428,
#    'ymin': 34.09138110683216,
#    'xmax': -116.4007370684428,
#    'ymax': 34.093381106832155}},
#  {'address': 'San Diego Ln, Victorville, California, 92394',
#   'location': {'x': -117.37396915064318, 'y': 34.5313305578859},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'San Diego Ln, Victorville, California, 92394',
#    'LongLabel': 'San Diego Ln, Victorville, CA, 92394, USA',
#    'ShortLabel': 'San Diego Ln',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'San Diego Ln, Victorville, California, 92394',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'San Diego',
#    'StType': 'Ln',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'San Diego Ln',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Victorville',
#    'MetroArea': '',
#    'Subregion': 'San Bernardino County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '92394',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.37396915064318,
#    'Y': 34.5313305578859,
#    'DisplayX': -117.37396915064318,
#    'DisplayY': 34.5313305578859,
#    'Xmin': -117.37496915064318,
#    'Xmax': -117.37296915064317,
#    'Ymin': 34.530330557885904,
#    'Ymax': 34.5323305578859,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.37496915064318,
#    'ymin': 34.530330557885904,
#    'xmax': -117.37296915064317,
#    'ymax': 34.5323305578859}},
#  {'address': 'San Diego Ave, Rancho Cucamonga, California, 91730',
#   'location': {'x': -117.61193153693705, 'y': 34.112854422504896},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'San Diego Ave, Rancho Cucamonga, California, 91730',
#    'LongLabel': 'San Diego Ave, Rancho Cucamonga, CA, 91730, USA',
#    'ShortLabel': 'San Diego Ave',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'San Diego Ave, Rancho Cucamonga, California, 91730',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'San Diego',
#    'StType': 'Ave',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'San Diego Ave',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Rancho Cucamonga',
#    'MetroArea': 'Inland Empire',
#    'Subregion': 'San Bernardino County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '91730',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -117.61193153693705,
#    'Y': 34.112854422504896,
#    'DisplayX': -117.61193153693705,
#    'DisplayY': 34.112854422504896,
#    'Xmin': -117.61293153693705,
#    'Xmax': -117.61093153693704,
#    'Ymin': 34.1118544225049,
#    'Ymax': 34.11385442250489,
#    'ExInfo': ''},
#   'extent': {'xmin': -117.61293153693705,
#    'ymin': 34.1118544225049,
#    'xmax': -117.61093153693704,
#    'ymax': 34.11385442250489}},
#  {'address': 'San Diego Fwy, Inglewood, California, 90304',
#   'location': {'x': -118.368504, 'y': 33.930940608962004},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'San Diego Fwy, Inglewood, California, 90304',
#    'LongLabel': 'San Diego Fwy, Inglewood, CA, 90304, USA',
#    'ShortLabel': 'San Diego Fwy',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'San Diego Fwy, Inglewood, California, 90304',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'San Diego',
#    'StType': 'Fwy',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'San Diego Fwy',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Inglewood',
#    'MetroArea': 'Los Angeles Metro Area',
#    'Subregion': 'Los Angeles County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '90304',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -118.368504,
#    'Y': 33.930940608962004,
#    'DisplayX': -118.368504,
#    'DisplayY': 33.930940608962004,
#    'Xmin': -118.369504,
#    'Xmax': -118.367504,
#    'Ymin': 33.929940608962006,
#    'Ymax': 33.931940608962,
#    'ExInfo': ''},
#   'extent': {'xmin': -118.369504,
#    'ymin': 33.929940608962006,
#    'xmax': -118.367504,
#    'ymax': 33.931940608962}},
#  {'address': 'San Diego Fwy, Gardena, California, 90248',
#   'location': {'x': -118.284633, 'y': 33.85685593106142},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'San Diego Fwy, Gardena, California, 90248',
#    'LongLabel': 'San Diego Fwy, Gardena, CA, 90248, USA',
#    'ShortLabel': 'San Diego Fwy',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'San Diego Fwy, Gardena, California, 90248',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'San Diego',
#    'StType': 'Fwy',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'San Diego Fwy',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Gardena',
#    'MetroArea': 'Los Angeles Metro Area',
#    'Subregion': 'Los Angeles County',
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '90248',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -118.284633,
#    'Y': 33.85685593106142,
#    'DisplayX': -118.284633,
#    'DisplayY': 33.85685593106142,
#    'Xmin': -118.285633,
#    'Xmax': -118.283633,
#    'Ymin': 33.85585593106142,
#    'Ymax': 33.857855931061415,
#    'ExInfo': ''},
#   'extent': {'xmin': -118.285633,
#    'ymin': 33.85585593106142,
#    'xmax': -118.283633,
#    'ymax': 33.857855931061415}}]

# %%
len(results)
# Out:
# 20

# %%
results[0]
# Out:
# {'address': 'San Diego, California',
#  'location': {'x': -117.16170999999997, 'y': 32.71568000000008},
#  'score': 100,
#  'attributes': {'Loc_name': 'World',
#   'Status': 'T',
#   'Score': 100,
#   'Match_addr': 'San Diego, California',
#   'LongLabel': 'San Diego, CA, USA',
#   'ShortLabel': 'San Diego',
#   'Addr_type': 'Locality',
#   'Type': 'City',
#   'PlaceName': 'San Diego',
#   'Place_addr': 'San Diego, California',
#   'Phone': '',
#   'URL': '',
#   'Rank': 2,
#   'AddBldg': '',
#   'AddNum': '',
#   'AddNumFrom': '',
#   'AddNumTo': '',
#   'AddRange': '',
#   'Side': '',
#   'StPreDir': '',
#   'StPreType': '',
#   'StName': '',
#   'StType': '',
#   'StDir': '',
#   'BldgType': '',
#   'BldgName': '',
#   'LevelType': '',
#   'LevelName': '',
#   'UnitType': '',
#   'UnitName': '',
#   'SubAddr': '',
#   'StAddr': '',
#   'Block': '',
#   'Sector': '',
#   'Nbrhd': '',
#   'District': '',
#   'City': 'San Diego',
#   'MetroArea': 'San Diego Metro Area',
#   'Subregion': 'San Diego County',
#   'Region': 'California',
#   'RegionAbbr': 'CA',
#   'Territory': '',
#   'Zone': '',
#   'Postal': '',
#   'PostalExt': '',
#   'Country': 'USA',
#   'LangCode': 'ENG',
#   'Distance': 0,
#   'X': -117.16170999999997,
#   'Y': 32.71568000000008,
#   'DisplayX': -117.16170999999997,
#   'DisplayY': 32.71568000000008,
#   'Xmin': -117.40070999999998,
#   'Xmax': -116.92270999999997,
#   'Ymin': 32.47668000000008,
#   'Ymax': 32.954680000000074,
#   'ExInfo': ''},
#  'extent': {'xmin': -117.40070999999998,
#   'ymin': 32.47668000000008,
#   'xmax': -116.92270999999997,
#   'ymax': 32.954680000000074}}

# %%
map1 = gis.map('San Diego, CA')
map1
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oc…

# %%
map1.draw(results[0]['location'])

# %% [markdown]
# ### Geocode single line addresses

# %%
r2 = geocoding.geocode('San Diego Convention center')
len(r2)
# Out:
# 20

# %%
[str(r['score']) +"  :  "+ r['attributes']['Match_addr'] for r in r2]
# Out:
# ['100  :  San Diego Convention Center',
#  '100  :  Convention Center',
#  '100  :  San Diego Concourse',
#  '100  :  Golden Hall',
#  '100  :  Hall H',
#  '100  :  Residence Inn-San Diego',
#  '100  :  SEAT Planners',
#  '100  :  San Diego Convention Center B Ent',
#  '100  :  San Diego Convention Center C Ent',
#  '100  :  San Diego Convention Center A Ent',
#  '100  :  San Diego Convention Center D Ent',
#  '100  :  San Diego Conv Ctr Mezzanine Ent',
#  '100  :  San Diego Convention Center ter Ent',
#  '100  :  San Diego Convention Center H Ent',
#  '100  :  San Diego Convention Center G Ent',
#  '100  :  San Diego Convention Center E Ent',
#  '100  :  San Diego Convention Center F Ent',
#  '100  :  The Observatory North Park',
#  '100  :  Palomar Christian Conference Center',
#  '100  :  Del Mar Fairgrounds']

# %% [markdown]
# ### Geocode multi field address

# %%
multi_field_address = { 
    "Address" : "111 Harbor Dr",
    "City" : "San Diego",
    "Region" : "CA",
    "Subregion":"San Diego",
    "Postal" : 92103,
    "Country":"USA"
    }
r_multi_fields = geocoding.geocode(multi_field_address)
len(r_multi_fields)
# Out:
# 15

# %% [markdown]
# ## Batch geocoding

# %%
addresses = ["380 New York St, Redlands, CA", 
             "1 World Way, Los Angeles, CA",
             "1200 Getty Center Drive, Los Angeles, CA", 
             "5905 Wilshire Boulevard, Los Angeles, CA",
             "100 Universal City Plaza, Universal City, CA 91608",
             "4800 Oak Grove Dr, Pasadena, CA 91109"]

# %%
results = geocoding.batch_geocode(addresses)

# %%
len(results)
# Out:
# 6

# %%
map5 = gis.map('Los Angeles, CA')
map5
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oc…

# %%
for address in results:
    map5.draw(address['location'])

# %% [markdown]
# ## Reverse geocoding

# %%
reverse_geocode_results = geocoding.reverse_geocode([2.2945, 48.8583])
reverse_geocode_results
# Out:
# {'address': {'Match_addr': 'Salle Gustave Eiffel',
#   'LongLabel': 'Salle Gustave Eiffel, Avenue Gustave Eiffel, 75007, 7e Arrondissement, Paris, Île-de-France, FRA',
#   'ShortLabel': 'Salle Gustave Eiffel',
#   'Addr_type': 'POI',
#   'Type': 'Convention Center',
#   'PlaceName': 'Salle Gustave Eiffel',
#   'AddNum': '',
#   'Address': 'Avenue Gustave Eiffel',
#   'Block': '',
#   'Sector': '',
#   'Neighborhood': 'Gros Caillou',
#   'District': '7e Arrondissement',
#   'City': 'Paris',
#   'MetroArea': '',
#   'Subregion': 'Paris',
#   'Region': 'Île-de-France',
#   'Territory': '',
#   'Postal': '75007',
#   'PostalExt': '',
#   'CountryCode': 'FRA'},
#  'location': {'x': 2.2951599583073303,
#   'y': 48.85784000836726,
#   'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}

# %%
map6 = gis.map('San Diego convention center, San Diego, CA', 16)
map6
# Out:
# MapView(basemaps=['dark-gray', 'dark-gray-vector', 'gray', 'gray-vector', 'hybrid', 'national-geographic', 'oc…
# Petco Park
# J Street Inn
# Park Blvd, San Diego, California, 92101
# Hotel Solamar

# %%
def find_addr(map6, g):
    try:
        map6.draw(g)
        geocoded = geocoding.reverse_geocode(g)
        print(geocoded['address']['Match_addr'])
    except:
        print("Couldn't match address. Try another place...")

# %%
map6.on_click(find_addr)
