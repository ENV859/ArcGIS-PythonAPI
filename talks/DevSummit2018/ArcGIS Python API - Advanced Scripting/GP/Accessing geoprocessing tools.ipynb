# %% [markdown]
# # Geoprocessing

# %%
import arcgis
from arcgis.gis import GIS
from IPython.display import display

# %%
gis = GIS('https://www.arcgis.com', 'arcgis_python', 'P@ssword123')

# %%
toolboxes = gis.content.search('Ocean Currents', 'Geoprocessing Toolbox', 
                               outside_org=True, max_items=3)

# %%
for toolbox in toolboxes:
    display(toolbox)
# Out:
# <Item title:"Farthest On Circle" type:Geoprocessing Toolbox owner:johnfry10>
# <Item title:"Ocean Currents" type:Geoprocessing Toolbox owner:esri_apac>
# <Item title:"SAR_User_Input" type:Geoprocessing Toolbox owner:ttmetoffice>

# %% [markdown]
# <a id="pythonic-representation-of-tools-and-toolboxes"></a>
# ## Pythonic representation of tools and toolboxes

# %%
from arcgis.geoprocessing import import_toolbox

# %%
ocean_currents_toolbox = toolboxes[1]
ocean_currents_toolbox
# Out:
# <Item title:"Ocean Currents" type:Geoprocessing Toolbox owner:esri_apac>

# %%
ocean_currents = import_toolbox(ocean_currents_toolbox)

# %%
ocean_currents.

# %% [markdown]
# <a id="tool-signature-parameters-and-documentation"></a>
# ## Tool signature, parameters and documentation

# %%
help(ocean_currents.message_in_a_bottle)
# Out:
# Help on function message_in_a_bottle:
#
# message_in_a_bottle(input_point:arcgis.features.feature.FeatureSet={'geometryType': 'esriGeometryPoint', 'Fields': [{'alias': 'FID', 'type': 'esriFieldTypeOID', 'name': 'FID'}, {'alias': 'Shape', 'type': 'esriFieldTypeGeometry', 'name': 'Shape'}, {'alias': 'Id', 'type': 'esriFieldTypeInteger', 'name': 'Id'}], 'spatialReference': {'wkid': 4326}, 'fields': [{'alias': 'FID', 'type': 'esriFieldTypeOID', 'name': 'FID'}, {'alias': 'Shape', 'type': 'esriFieldTypeGeometry', 'name': 'Shape'}, {'alias': 'Id', 'type': 'esriFieldTypeInteger', 'name': 'Id'}]}, days:float=150, gis=None) -> arcgis.features.feature.FeatureSet
#
#
#
#     Parameters:
#
#        input_point: Input Point (FeatureSet). Required parameter.
#
#        days: Days (float). Required parameter.
#
#             gis: Optional, the GIS on which this tool runs. If not specified, the active GIS is used.
#
#
#     Returns:
#        output - Output as a FeatureSet
#
#     See http://sampleserver1c.arcgisonline.com/arcgisoutput/Specialty_ESRI_Currents_World/MessageInABottle.htm for additional help.
