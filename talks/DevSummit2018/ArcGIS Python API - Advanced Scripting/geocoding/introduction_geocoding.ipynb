# %% [markdown]
# # An introduction to geocoding
#
# Geocoders are tools to which you pass in an address / place of interest and it gives back the coordinates of that place.
#
# The **`arcgis.geocoding`** module provides types and functions for geocoding, batch geocoding and reverse geocoding.

# %%
from arcgis.gis import GIS
from arcgis import geocoding
from getpass import getpass
password = getpass()
# Out:
# ········

# %%
gis = GIS("http://www.arcgis.com", "arcgis_python", password)

# %% [markdown]
# ## Geocoding addresses
# All geocoding operations are handled by `geocode()` function. It can geocode
#
#  1. single line address
#  2. multi field address
#  3. points of interest
#  4. administrative place names
#  5. postal codes

# %%
results = geocoding.geocode('San Diego, CA')
results
# Out:
# [{'address': 'San Diego, California',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'Locality',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'San Diego',
#    'Country': 'USA',
#    'DisplayX': -117.16170999999997,
#    'DisplayY': 32.71568000000008,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San Diego, CA, USA',
#    'Match_addr': 'San Diego, California',
#    'MetroArea': 'San Diego Metro Area',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Diego, California',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 2,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'San Diego',
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Diego',
#    'Territory': '',
#    'Type': 'City',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -117.16170999999997,
#    'Xmax': -116.92370999999997,
#    'Xmin': -117.39970999999997,
#    'Y': 32.71568000000008,
#    'Ymax': 32.95368000000008,
#    'Ymin': 32.47768000000008,
#    'Zone': ''},
#   'extent': {'xmax': -116.92370999999997,
#    'xmin': -117.39970999999997,
#    'ymax': 32.95368000000008,
#    'ymin': 32.47768000000008},
#   'location': {'x': -117.16170999999997, 'y': 32.71568000000008},
#   'score': 100},
#  {'address': 'San Diego, Carabobo',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'Locality',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': '',
#    'Country': 'VEN',
#    'DisplayX': -67.95480999999995,
#    'DisplayY': 10.257310000000075,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'SPA',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San Diego, Carabobo, VEN',
#    'Match_addr': 'San Diego, Carabobo',
#    'MetroArea': '',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'Carabobo',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 8.51,
#    'Region': 'Carabobo',
#    'RegionAbbr': '',
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'San Diego',
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Diego',
#    'Territory': '',
#    'Type': 'City',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -67.95480999999995,
#    'Xmax': -67.87480999999995,
#    'Xmin': -68.03480999999995,
#    'Y': 10.257310000000075,
#    'Ymax': 10.337310000000075,
#    'Ymin': 10.177310000000075,
#    'Zone': ''},
#   'extent': {'xmax': -67.87480999999995,
#    'xmin': -68.03480999999995,
#    'ymax': 10.337310000000075,
#    'ymin': 10.177310000000075},
#   'location': {'x': -67.95480999999995, 'y': 10.257310000000075},
#   'score': 100},
#  {'address': 'San-Diego',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'POI',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'San Diego',
#    'Country': 'USA',
#    'DisplayX': -117.19743999999997,
#    'DisplayY': 32.732350000000054,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San-Diego, San Diego, CA, USA',
#    'Match_addr': 'San-Diego',
#    'MetroArea': '',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'San-Diego',
#    'Place_addr': 'San Diego, California',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 9,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'San-Diego',
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Diego County',
#    'Territory': '',
#    'Type': 'Airport',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -117.19743999999997,
#    'Xmax': -117.17243999999997,
#    'Xmin': -117.22243999999998,
#    'Y': 32.732350000000054,
#    'Ymax': 32.75735000000005,
#    'Ymin': 32.707350000000055,
#    'Zone': ''},
#   'extent': {'xmax': -117.17243999999997,
#    'xmin': -117.22243999999998,
#    'ymax': 32.75735000000005,
#    'ymin': 32.707350000000055},
#   'location': {'x': -117.19743999999997, 'y': 32.732350000000054},
#   'score': 100},
#  {'address': 'San Diego, California',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'Locality',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': '',
#    'Country': 'USA',
#    'DisplayX': -116.73527631899998,
#    'DisplayY': 33.034055591000026,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San Diego, CA, USA',
#    'Match_addr': 'San Diego, California',
#    'MetroArea': '',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'California',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 10,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'San Diego',
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Diego',
#    'Territory': '',
#    'Type': 'County',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -116.73527631899998,
#    'Xmax': -116.11227631899997,
#    'Xmin': -117.35827631899998,
#    'Y': 33.034055591000026,
#    'Ymax': 33.657055591000024,
#    'Ymin': 32.41105559100003,
#    'Zone': ''},
#   'extent': {'xmax': -116.11227631899997,
#    'xmin': -117.35827631899998,
#    'ymax': 33.657055591000024,
#    'ymin': 32.41105559100003},
#   'location': {'x': -116.73527631899998, 'y': 33.034055591000026},
#   'score': 100},
#  {'address': 'San-Diego, San Diego, California',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'Locality',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'San Diego',
#    'Country': 'USA',
#    'DisplayX': -117.15725999999995,
#    'DisplayY': 32.71533000000005,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San-Diego, San Diego, CA, USA',
#    'Match_addr': 'San-Diego, San Diego, California',
#    'MetroArea': '',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'San-Diego',
#    'Place_addr': 'San Diego, California',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 10,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'San-Diego',
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Diego',
#    'Territory': '',
#    'Type': 'City',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -117.15725999999995,
#    'Xmax': -116.91925999999995,
#    'Xmin': -117.39525999999995,
#    'Y': 32.71533000000005,
#    'Ymax': 32.95333000000005,
#    'Ymin': 32.47733000000005,
#    'Zone': ''},
#   'extent': {'xmax': -116.91925999999995,
#    'xmin': -117.39525999999995,
#    'ymax': 32.95333000000005,
#    'ymin': 32.47733000000005},
#   'location': {'x': -117.15725999999995, 'y': 32.71533000000005},
#   'score': 100},
#  {'address': 'San Diego, San Roque, Cádiz, Andalucía',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'Locality',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'San Roque',
#    'Country': 'ESP',
#    'DisplayX': -5.256909999999948,
#    'DisplayY': 36.31313000000006,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'SPA',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San Diego, San Roque, Cádiz, Andalucía, ESP',
#    'Match_addr': 'San Diego, San Roque, Cádiz, Andalucía',
#    'MetroArea': '',
#    'Nbrhd': 'San Diego',
#    'Phone': '',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Roque, Cádiz, Andalucía',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 15,
#    'Region': 'Andalucía',
#    'RegionAbbr': '',
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'San Diego',
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'Cádiz',
#    'Territory': '',
#    'Type': 'Village',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -5.256909999999948,
#    'Xmax': -5.246909999999948,
#    'Xmin': -5.266909999999948,
#    'Y': 36.31313000000006,
#    'Ymax': 36.323130000000056,
#    'Ymin': 36.30313000000006,
#    'Zone': ''},
#   'extent': {'xmax': -5.246909999999948,
#    'xmin': -5.266909999999948,
#    'ymax': 36.323130000000056,
#    'ymin': 36.30313000000006},
#   'location': {'x': -5.256909999999948, 'y': 36.31313000000006},
#   'score': 100},
#  {'address': 'San Diego',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'POI',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'San Diego',
#    'Country': 'VEN',
#    'DisplayX': -67.96346999999997,
#    'DisplayY': 10.208500000000072,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'SPA',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San Diego, Valencia, San Diego, Carabobo, VEN',
#    'Match_addr': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Diego, Valencia, San Diego, Carabobo',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 19,
#    'Region': 'Carabobo',
#    'RegionAbbr': '',
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'San Diego',
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Diego',
#    'Territory': '',
#    'Type': 'Grocery',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -67.96346999999997,
#    'Xmax': -67.95846999999998,
#    'Xmin': -67.96846999999997,
#    'Y': 10.208500000000072,
#    'Ymax': 10.213500000000073,
#    'Ymin': 10.203500000000071,
#    'Zone': ''},
#   'extent': {'xmax': -67.95846999999998,
#    'xmin': -67.96846999999997,
#    'ymax': 10.213500000000073,
#    'ymin': 10.203500000000071},
#   'location': {'x': -67.96346999999997, 'y': 10.208500000000072},
#   'score': 100},
#  {'address': 'San Diego',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'POI',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'San Diego',
#    'Country': 'VEN',
#    'DisplayX': -67.96510999999998,
#    'DisplayY': 10.221920000000068,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'SPA',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San Diego, Valencia, San Diego, Carabobo, VEN',
#    'Match_addr': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Diego, Valencia, San Diego, Carabobo',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 19,
#    'Region': 'Carabobo',
#    'RegionAbbr': '',
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'San Diego',
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Diego',
#    'Territory': '',
#    'Type': 'Grocery',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -67.96510999999998,
#    'Xmax': -67.96010999999999,
#    'Xmin': -67.97010999999998,
#    'Y': 10.221920000000068,
#    'Ymax': 10.226920000000069,
#    'Ymin': 10.216920000000068,
#    'Zone': ''},
#   'extent': {'xmax': -67.96010999999999,
#    'xmin': -67.97010999999998,
#    'ymax': 10.226920000000069,
#    'ymin': 10.216920000000068},
#   'location': {'x': -67.96510999999998, 'y': 10.221920000000068},
#   'score': 100},
#  {'address': 'San Diego',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'POI',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'San Diego',
#    'Country': 'VEN',
#    'DisplayX': -67.96510999999998,
#    'DisplayY': 10.221920000000068,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'SPA',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San Diego, Valencia, San Diego, Carabobo, VEN',
#    'Match_addr': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Diego, Valencia, San Diego, Carabobo',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 19,
#    'Region': 'Carabobo',
#    'RegionAbbr': '',
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'San Diego',
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Diego',
#    'Territory': '',
#    'Type': 'Pharmacy',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -67.96510999999998,
#    'Xmax': -67.96010999999999,
#    'Xmin': -67.97010999999998,
#    'Y': 10.221920000000068,
#    'Ymax': 10.226920000000069,
#    'Ymin': 10.216920000000068,
#    'Zone': ''},
#   'extent': {'xmax': -67.96010999999999,
#    'xmin': -67.97010999999998,
#    'ymax': 10.226920000000069,
#    'ymin': 10.216920000000068},
#   'location': {'x': -67.96510999999998, 'y': 10.221920000000068},
#   'score': 100},
#  {'address': 'San Diego',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'POI',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'San Diego',
#    'Country': 'VEN',
#    'DisplayX': -67.96511999999996,
#    'DisplayY': 10.222920000000045,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'SPA',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San Diego, Valencia, San Diego, Carabobo, VEN',
#    'Match_addr': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'San Diego, Valencia, San Diego, Carabobo',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 19,
#    'Region': 'Carabobo',
#    'RegionAbbr': '',
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'San Diego',
#    'Side': '',
#    'StAddr': '',
#    'StDir': '',
#    'StName': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Diego',
#    'Territory': '',
#    'Type': 'Shopping Center',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -67.96511999999996,
#    'Xmax': -67.96011999999996,
#    'Xmin': -67.97011999999995,
#    'Y': 10.222920000000045,
#    'Ymax': 10.227920000000045,
#    'Ymin': 10.217920000000044,
#    'Zone': ''},
#   'extent': {'xmax': -67.96011999999996,
#    'xmin': -67.97011999999995,
#    'ymax': 10.227920000000045,
#    'ymin': 10.217920000000044},
#   'location': {'x': -67.96511999999996, 'y': 10.222920000000045},
#   'score': 100},
#  {'address': 'San Diego',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'POI',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'San Diego',
#    'Country': 'VEN',
#    'DisplayX': -67.96749999999997,
#    'DisplayY': 10.194800000000043,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'SPA',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San Diego, Calle 102, San Diego, Valencia, San Diego, Carabobo, VEN',
#    'Match_addr': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'Calle 102, San Diego, Valencia, San Diego, Carabobo',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 19,
#    'Region': 'Carabobo',
#    'RegionAbbr': '',
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'San Diego',
#    'Side': '',
#    'StAddr': 'Calle 102',
#    'StDir': '',
#    'StName': '102',
#    'StPreDir': '',
#    'StPreType': 'Calle',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Diego',
#    'Territory': '',
#    'Type': 'Hotel',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -67.96749999999997,
#    'Xmax': -67.96249999999998,
#    'Xmin': -67.97249999999997,
#    'Y': 10.194800000000043,
#    'Ymax': 10.199800000000044,
#    'Ymin': 10.189800000000043,
#    'Zone': ''},
#   'extent': {'xmax': -67.96249999999998,
#    'xmin': -67.97249999999997,
#    'ymax': 10.199800000000044,
#    'ymin': 10.189800000000043},
#   'location': {'x': -67.96749999999997, 'y': 10.194800000000043},
#   'score': 100},
#  {'address': 'San Diego',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'POI',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'San Diego',
#    'Country': 'VEN',
#    'DisplayX': -67.95372999999995,
#    'DisplayY': 10.256020000000035,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'SPA',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San Diego, Avenida Sucre, San Diego, Valencia, San Diego, Carabobo, VEN',
#    'Match_addr': 'San Diego',
#    'MetroArea': 'Valencia',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': 'San Diego',
#    'Place_addr': 'Avenida Sucre, San Diego, Valencia, San Diego, Carabobo',
#    'Postal': '',
#    'PostalExt': '',
#    'Rank': 19,
#    'Region': 'Carabobo',
#    'RegionAbbr': '',
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'San Diego',
#    'Side': '',
#    'StAddr': 'Avenida Sucre',
#    'StDir': '',
#    'StName': 'Sucre',
#    'StPreDir': '',
#    'StPreType': 'Avenida',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Diego',
#    'Territory': '',
#    'Type': 'Church',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -67.95372999999995,
#    'Xmax': -67.94872999999995,
#    'Xmin': -67.95872999999995,
#    'Y': 10.256020000000035,
#    'Ymax': 10.261020000000036,
#    'Ymin': 10.251020000000034,
#    'Zone': ''},
#   'extent': {'xmax': -67.94872999999995,
#    'xmin': -67.95872999999995,
#    'ymax': 10.261020000000036,
#    'ymin': 10.251020000000034},
#   'location': {'x': -67.95372999999995, 'y': 10.256020000000035},
#   'score': 100},
#  {'address': 'San Diego, Yountville, California, 94599',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'StreetName',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'Yountville',
#    'Country': 'USA',
#    'DisplayX': -122.35384575,
#    'DisplayY': 38.40025050000001,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San Diego, Yountville, CA, 94599, USA',
#    'Match_addr': 'San Diego, Yountville, California, 94599',
#    'MetroArea': 'San Francisco Bay Area',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': '',
#    'Place_addr': 'San Diego, Yountville, California, 94599',
#    'Postal': '94599',
#    'PostalExt': '',
#    'Rank': 20,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Score': 100,
#    'Sector': '',
#    'ShortLabel': 'San Diego',
#    'Side': '',
#    'StAddr': 'San Diego',
#    'StDir': '',
#    'StName': 'San Diego',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': '',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'Napa',
#    'Territory': '',
#    'Type': '',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -122.35384575,
#    'Xmax': -122.35284575,
#    'Xmin': -122.35484575000001,
#    'Y': 38.40025050000001,
#    'Ymax': 38.40125050000001,
#    'Ymin': 38.399250500000015,
#    'Zone': ''},
#   'extent': {'xmax': -122.35284575,
#    'xmin': -122.35484575000001,
#    'ymax': 38.40125050000001,
#    'ymin': 38.399250500000015},
#   'location': {'x': -122.35384575, 'y': 38.40025050000001},
#   'score': 100},
#  {'address': 'California St, San Diego, California, 92110',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'StreetName',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'San Diego',
#    'Country': 'USA',
#    'DisplayX': -117.18497305344265,
#    'DisplayY': 32.744990510932766,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'California St, San Diego, CA, 92110, USA',
#    'Match_addr': 'California St, San Diego, California, 92110',
#    'MetroArea': 'San Diego Metro Area',
#    'Nbrhd': 'Mission Hills',
#    'Phone': '',
#    'PlaceName': '',
#    'Place_addr': 'California St, San Diego, California, 92110',
#    'Postal': '92110',
#    'PostalExt': '',
#    'Rank': 20,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Score': 97.35,
#    'Sector': '',
#    'ShortLabel': 'California St',
#    'Side': '',
#    'StAddr': 'California St',
#    'StDir': '',
#    'StName': 'California',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': 'St',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Diego',
#    'Territory': '',
#    'Type': '',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -117.18497305344265,
#    'Xmax': -117.18397305344264,
#    'Xmin': -117.18597305344265,
#    'Y': 32.744990510932766,
#    'Ymax': 32.745990510932764,
#    'Ymin': 32.74399051093277,
#    'Zone': ''},
#   'extent': {'xmax': -117.18397305344264,
#    'xmin': -117.18597305344265,
#    'ymax': 32.745990510932764,
#    'ymin': 32.74399051093277},
#   'location': {'x': -117.18497305344265, 'y': 32.744990510932766},
#   'score': 97.35},
#  {'address': 'California St, San Diego, California, 92101',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'StreetName',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'San Diego',
#    'Country': 'USA',
#    'DisplayX': -117.1806891927498,
#    'DisplayY': 32.74010843605822,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'California St, San Diego, CA, 92101, USA',
#    'Match_addr': 'California St, San Diego, California, 92101',
#    'MetroArea': 'San Diego Metro Area',
#    'Nbrhd': 'Middletown',
#    'Phone': '',
#    'PlaceName': '',
#    'Place_addr': 'California St, San Diego, California, 92101',
#    'Postal': '92101',
#    'PostalExt': '',
#    'Rank': 20,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Score': 97.35,
#    'Sector': '',
#    'ShortLabel': 'California St',
#    'Side': '',
#    'StAddr': 'California St',
#    'StDir': '',
#    'StName': 'California',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': 'St',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Diego',
#    'Territory': '',
#    'Type': '',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -117.1806891927498,
#    'Xmax': -117.17968919274979,
#    'Xmin': -117.1816891927498,
#    'Y': 32.74010843605822,
#    'Ymax': 32.74110843605822,
#    'Ymin': 32.739108436058224,
#    'Zone': ''},
#   'extent': {'xmax': -117.17968919274979,
#    'xmin': -117.1816891927498,
#    'ymax': 32.74110843605822,
#    'ymin': 32.739108436058224},
#   'location': {'x': -117.1806891927498, 'y': 32.74010843605822},
#   'score': 97.35},
#  {'address': 'California St, San Diego, California, 92101',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'StreetName',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'San Diego',
#    'Country': 'USA',
#    'DisplayX': -117.17192415209873,
#    'DisplayY': 32.727582353261575,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'California St, San Diego, CA, 92101, USA',
#    'Match_addr': 'California St, San Diego, California, 92101',
#    'MetroArea': 'San Diego Metro Area',
#    'Nbrhd': 'Midway District',
#    'Phone': '',
#    'PlaceName': '',
#    'Place_addr': 'California St, San Diego, California, 92101',
#    'Postal': '92101',
#    'PostalExt': '',
#    'Rank': 20,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Score': 97.35,
#    'Sector': '',
#    'ShortLabel': 'California St',
#    'Side': '',
#    'StAddr': 'California St',
#    'StDir': '',
#    'StName': 'California',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': 'St',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'San Diego',
#    'Territory': '',
#    'Type': '',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -117.17192415209873,
#    'Xmax': -117.17092415209872,
#    'Xmin': -117.17292415209873,
#    'Y': 32.727582353261575,
#    'Ymax': 32.72858235326157,
#    'Ymin': 32.72658235326158,
#    'Zone': ''},
#   'extent': {'xmax': -117.17092415209872,
#    'xmin': -117.17292415209873,
#    'ymax': 32.72858235326157,
#    'ymin': 32.72658235326158},
#   'location': {'x': -117.17192415209873, 'y': 32.727582353261575},
#   'score': 97.35},
#  {'address': 'San Diego Dr, Vallejo, California, 94590',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'StreetName',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'Vallejo',
#    'Country': 'USA',
#    'DisplayX': -122.23325694975456,
#    'DisplayY': 38.089074284146704,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San Diego Dr, Vallejo, CA, 94590, USA',
#    'Match_addr': 'San Diego Dr, Vallejo, California, 94590',
#    'MetroArea': 'San Francisco Bay Area',
#    'Nbrhd': 'Carquinez Heights',
#    'Phone': '',
#    'PlaceName': '',
#    'Place_addr': 'San Diego Dr, Vallejo, California, 94590',
#    'Postal': '94590',
#    'PostalExt': '',
#    'Rank': 20,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Score': 97.35,
#    'Sector': '',
#    'ShortLabel': 'San Diego Dr',
#    'Side': '',
#    'StAddr': 'San Diego Dr',
#    'StDir': '',
#    'StName': 'San Diego',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': 'Dr',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'Solano',
#    'Territory': '',
#    'Type': '',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -122.23325694975456,
#    'Xmax': -122.23225694975456,
#    'Xmin': -122.23425694975457,
#    'Y': 38.089074284146704,
#    'Ymax': 38.0900742841467,
#    'Ymin': 38.08807428414671,
#    'Zone': ''},
#   'extent': {'xmax': -122.23225694975456,
#    'xmin': -122.23425694975457,
#    'ymax': 38.0900742841467,
#    'ymin': 38.08807428414671},
#   'location': {'x': -122.23325694975456, 'y': 38.089074284146704},
#   'score': 97.35},
#  {'address': 'San Diego St, Fairfield, California, 94533',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'StreetName',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'Fairfield',
#    'Country': 'USA',
#    'DisplayX': -122.0258565,
#    'DisplayY': 38.260107,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San Diego St, Fairfield, CA, 94533, USA',
#    'Match_addr': 'San Diego St, Fairfield, California, 94533',
#    'MetroArea': 'San Francisco Bay Area',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': '',
#    'Place_addr': 'San Diego St, Fairfield, California, 94533',
#    'Postal': '94533',
#    'PostalExt': '',
#    'Rank': 20,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Score': 97.35,
#    'Sector': '',
#    'ShortLabel': 'San Diego St',
#    'Side': '',
#    'StAddr': 'San Diego St',
#    'StDir': '',
#    'StName': 'San Diego',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': 'St',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'Solano',
#    'Territory': '',
#    'Type': '',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -122.0258565,
#    'Xmax': -122.0248565,
#    'Xmin': -122.02685650000001,
#    'Y': 38.260107,
#    'Ymax': 38.261106999999996,
#    'Ymin': 38.259107,
#    'Zone': ''},
#   'extent': {'xmax': -122.0248565,
#    'xmin': -122.02685650000001,
#    'ymax': 38.261106999999996,
#    'ymin': 38.259107},
#   'location': {'x': -122.0258565, 'y': 38.260107},
#   'score': 97.35},
#  {'address': 'San Diego Pl, San Ramon, California, 94583',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'StreetName',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'San Ramon',
#    'Country': 'USA',
#    'DisplayX': -121.9439532218467,
#    'DisplayY': 37.751502068909495,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San Diego Pl, San Ramon, CA, 94583, USA',
#    'Match_addr': 'San Diego Pl, San Ramon, California, 94583',
#    'MetroArea': 'San Francisco Bay Area',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': '',
#    'Place_addr': 'San Diego Pl, San Ramon, California, 94583',
#    'Postal': '94583',
#    'PostalExt': '',
#    'Rank': 20,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Score': 97.35,
#    'Sector': '',
#    'ShortLabel': 'San Diego Pl',
#    'Side': '',
#    'StAddr': 'San Diego Pl',
#    'StDir': '',
#    'StName': 'San Diego',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': 'Pl',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'Contra Costa',
#    'Territory': '',
#    'Type': '',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -121.9439532218467,
#    'Xmax': -121.9429532218467,
#    'Xmin': -121.9449532218467,
#    'Y': 37.751502068909495,
#    'Ymax': 37.75250206890949,
#    'Ymin': 37.7505020689095,
#    'Zone': ''},
#   'extent': {'xmax': -121.9429532218467,
#    'xmin': -121.9449532218467,
#    'ymax': 37.75250206890949,
#    'ymin': 37.7505020689095},
#   'location': {'x': -121.9439532218467, 'y': 37.751502068909495},
#   'score': 97.35},
#  {'address': 'San Diego St, San Pablo, California, 94806',
#   'attributes': {'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Addr_type': 'StreetName',
#    'BldgName': '',
#    'BldgType': '',
#    'Block': '',
#    'City': 'San Pablo',
#    'Country': 'USA',
#    'DisplayX': -122.3393532232915,
#    'DisplayY': 37.96523085467199,
#    'Distance': 0,
#    'District': '',
#    'ExInfo': '',
#    'LangCode': 'ENG',
#    'LevelName': '',
#    'LevelType': '',
#    'Loc_name': 'World',
#    'LongLabel': 'San Diego St, San Pablo, CA, 94806, USA',
#    'Match_addr': 'San Diego St, San Pablo, California, 94806',
#    'MetroArea': 'San Francisco Bay Area',
#    'Nbrhd': '',
#    'Phone': '',
#    'PlaceName': '',
#    'Place_addr': 'San Diego St, San Pablo, California, 94806',
#    'Postal': '94806',
#    'PostalExt': '',
#    'Rank': 20,
#    'Region': 'California',
#    'RegionAbbr': 'CA',
#    'Score': 97.35,
#    'Sector': '',
#    'ShortLabel': 'San Diego St',
#    'Side': '',
#    'StAddr': 'San Diego St',
#    'StDir': '',
#    'StName': 'San Diego',
#    'StPreDir': '',
#    'StPreType': '',
#    'StType': 'St',
#    'Status': 'T',
#    'SubAddr': '',
#    'Subregion': 'Contra Costa',
#    'Territory': '',
#    'Type': '',
#    'URL': '',
#    'UnitName': '',
#    'UnitType': '',
#    'X': -122.3393532232915,
#    'Xmax': -122.33835322329149,
#    'Xmin': -122.3403532232915,
#    'Y': 37.96523085467199,
#    'Ymax': 37.966230854671984,
#    'Ymin': 37.96423085467199,
#    'Zone': ''},
#   'extent': {'xmax': -122.33835322329149,
#    'xmin': -122.3403532232915,
#    'ymax': 37.966230854671984,
#    'ymin': 37.96423085467199},
#   'location': {'x': -122.3393532232915, 'y': 37.96523085467199},
#   'score': 97.35}]

# %%
len(results)
# Out:
# 20

# %%
results[0]
# Out:
# {'address': 'San Diego, California',
#  'attributes': {'AddBldg': '',
#   'AddNum': '',
#   'AddNumFrom': '',
#   'AddNumTo': '',
#   'AddRange': '',
#   'Addr_type': 'Locality',
#   'BldgName': '',
#   'BldgType': '',
#   'Block': '',
#   'City': 'San Diego',
#   'Country': 'USA',
#   'DisplayX': -117.16170999999997,
#   'DisplayY': 32.71568000000008,
#   'Distance': 0,
#   'District': '',
#   'ExInfo': '',
#   'LangCode': 'ENG',
#   'LevelName': '',
#   'LevelType': '',
#   'Loc_name': 'World',
#   'LongLabel': 'San Diego, CA, USA',
#   'Match_addr': 'San Diego, California',
#   'MetroArea': 'San Diego Metro Area',
#   'Nbrhd': '',
#   'Phone': '',
#   'PlaceName': 'San Diego',
#   'Place_addr': 'San Diego, California',
#   'Postal': '',
#   'PostalExt': '',
#   'Rank': 2,
#   'Region': 'California',
#   'RegionAbbr': 'CA',
#   'Score': 100,
#   'Sector': '',
#   'ShortLabel': 'San Diego',
#   'Side': '',
#   'StAddr': '',
#   'StDir': '',
#   'StName': '',
#   'StPreDir': '',
#   'StPreType': '',
#   'StType': '',
#   'Status': 'T',
#   'SubAddr': '',
#   'Subregion': 'San Diego',
#   'Territory': '',
#   'Type': 'City',
#   'URL': '',
#   'UnitName': '',
#   'UnitType': '',
#   'X': -117.16170999999997,
#   'Xmax': -116.92370999999997,
#   'Xmin': -117.39970999999997,
#   'Y': 32.71568000000008,
#   'Ymax': 32.95368000000008,
#   'Ymin': 32.47768000000008,
#   'Zone': ''},
#  'extent': {'xmax': -116.92370999999997,
#   'xmin': -117.39970999999997,
#   'ymax': 32.95368000000008,
#   'ymin': 32.47768000000008},
#  'location': {'x': -117.16170999999997, 'y': 32.71568000000008},
#  'score': 100}

# %%
map1 = gis.map('San Diego, CA')
map1

# %%
map1.draw(results[0]['location'])

# %% [markdown]
# ### Geocode single line addresses

# %%
r2 = geocoding.geocode('San Diego Convention center')
len(r2)
# Out:
# 20

# %%
[str(r['score']) +"  :  "+ r['attributes']['Match_addr'] for r in r2]
# Out:
# ['100  :  San Diego Convention Center',
#  '100  :  Convention Center',
#  '100  :  San Diego Conv Ctr Mezzanine Ent',
#  '100  :  San Diego Convention Center B Ent',
#  '100  :  San Diego Convention Center C Ent',
#  '100  :  San Diego Convention Center A Ent',
#  '100  :  San Diego Convention Center D Ent',
#  '100  :  San Diego Convention Center E Ent',
#  '100  :  San Diego Convention Center F Ent',
#  '100  :  San Diego Convention Center ter Ent',
#  '100  :  San Diego Convention Center H Ent',
#  '100  :  San Diego Convention Center G Ent',
#  '100  :  Palomar Christian Conference Center',
#  '100  :  Del Mar Fairgrounds',
#  '100  :  Gonzalo Jimenez Quesada',
#  '100  :  Downtown',
#  '97.35  :  Convention Center Ct, San Diego, California, 92101',
#  '95.71  :  San Diego Convention Center Corp',
#  '95.59  :  Convention Way, San Diego, California, 92101',
#  '83.9  :  Days Inn-San Diego-Convention Center']

# %% [markdown]
# ### Geocode multi field address

# %%
multi_field_address = { 
    "Address" : "111 Harbor Dr",
    "City" : "San Diego",
    "Region" : "CA",
    "Subregion":"San Diego",
    "Postal" : 92103,
    "Country":"USA"
    }
r_multi_fields = geocoding.geocode(multi_field_address)
len(r_multi_fields)
# Out:
# 20

# %% [markdown]
# ### Searching within an exent
# Find restaurants within walking distance of this training center (Hard Rock Hotel, Palm Springs)

# %%
# first create an extent.
conv_center = geocoding.geocode('San Diego Convention Center, California')[0]
map3 = gis.map('San Diego Convention Center', zoomlevel=17)
map3

# %%
restaurants = geocoding.geocode('grocery',search_extent=conv_center['extent'], 
                                max_locations=15)
len(restaurants)
# Out:
# 1

# %%
map3.clear_graphics()

# %%
for shop in restaurants:
    popup = { 
    "title" : shop['attributes']['PlaceName'], 
    "content" : shop['attributes']['Place_addr']
    }
    map3.draw(shop['location'],popup)

# %% [markdown]
# ## Batch geocoding

# %%
addresses = ["380 New York St, Redlands, CA", 
             "1 World Way, Los Angeles, CA",
             "1200 Getty Center Drive, Los Angeles, CA", 
             "5905 Wilshire Boulevard, Los Angeles, CA",
             "100 Universal City Plaza, Universal City, CA 91608",
             "4800 Oak Grove Dr, Pasadena, CA 91109"]

# %%
results = geocoding.batch_geocode(addresses)

# %%
len(results)
# Out:
# 6

# %%
map5 = gis.map('Los Angeles, CA')
map5

# %%
for address in results:
    map5.draw(address['location'])

# %% [markdown]
# ## Reverse geocoding

# %%
reverse_geocode_results = geocoding.reverse_geocode([2.2945, 48.8583])
reverse_geocode_results
# Out:
# {'address': {'AddNum': '',
#   'Addr_type': 'POI',
#   'Address': 'Avenue Gustave Eiffel',
#   'Block': '',
#   'City': 'Paris',
#   'CountryCode': 'FRA',
#   'District': '7e Arrondissement',
#   'LongLabel': 'Salle Gustave Eiffel, Avenue Gustave Eiffel, 75007, 7e Arrondissement, Paris, Île-de-France, FRA',
#   'Match_addr': 'Salle Gustave Eiffel',
#   'MetroArea': '',
#   'Neighborhood': 'Gros Caillou',
#   'PlaceName': 'Salle Gustave Eiffel',
#   'Postal': '75007',
#   'PostalExt': '',
#   'Region': 'Île-de-France',
#   'Sector': '',
#   'ShortLabel': 'Salle Gustave Eiffel',
#   'Subregion': 'Paris',
#   'Territory': '',
#   'Type': 'Convention Center'},
#  'location': {'spatialReference': {'latestWkid': 4326, 'wkid': 4326},
#   'x': 2.295159958307296,
#   'y': 48.8578400083672}}

# %%
map6 = gis.map('San Diego convention center, San Diego, CA', 16)
map6

# %%
def find_addr(map6, g):
    try:
        map6.draw(g)
        geocoded = geocoding.reverse_geocode(g)
        print(geocoded['address']['Match_addr'])
    except:
        print("Couldn't match address. Try another place...")

# %%
map6.on_click(find_addr)
