# %%
# connect to ArcGIS Online
from arcgis.gis import GIS
from arcgis.geoprocessing import import_toolbox
gis = GIS()

# %% [markdown]
# # Viewshed tool

# %%
viewshed = import_toolbox('http://sampleserver1.arcgisonline.com/ArcGIS/rest/services/Elevation/ESRI_Elevation_World/GPServer')

# %%
help(viewshed.viewshed)
# Out:
# Help on function viewshed:
#
# viewshed(input_observation_point:arcgis.features.feature.FeatureSet={'geometryType': 'esriGeometryPoint', 'fields': [{'alias': 'FID', 'type': 'esriFieldTypeOID', 'name': 'FID'}, {'alias': 'Shape', 'type': 'esriFieldTypeGeometry', 'name': 'Shape'}, {'alias': 'OffsetA', 'type': 'esriFieldTypeDouble', 'name': 'OffsetA'}], 'spatialReference': {'wkid': 54003}, 'Fields': [{'alias': 'FID', 'type': 'esriFieldTypeOID', 'name': 'FID'}, {'alias': 'Shape', 'type': 'esriFieldTypeGeometry', 'name': 'Shape'}, {'alias': 'OffsetA', 'type': 'esriFieldTypeDouble', 'name': 'OffsetA'}]}, viewshed_distance:arcgis.geoprocessing._types.LinearUnit={'distance': 15000, 'units': 'esriMeters'}, gis=None) -> arcgis.features.feature.FeatureSet
#
#
#
#     Parameters:
#
#        input_observation_point: Input Observation Point (FeatureSet). Required parameter.
#
#        viewshed_distance: Viewshed Distance (LinearUnit). Required parameter.
#
#             gis: Optional, the GIS on which this tool runs. If not specified, the active GIS is used.
#
#
#     Returns:
#        viewshed_result - Viewshed Result as a FeatureSet
#
#     See http://sampleserver1b.arcgisonline.com/arcgisoutput/Elevation_ESRI_Elevation_World/Viewshed.htm for additional help.

# %%
import arcgis
arcgis.env.out_spatial_reference = 4326

# %%
map = gis.map('South San Francisco', zoomlevel=12)
map
# Out:
# {"geometryType": "esriGeometryPolygon", "fields": {"fields": []}, "spatialReference": {"wkid": 4326}, "features": [{"geometry": {"rings": [[[-122.41822247899995, 37.73470322400004], [-122.41923160399995, 37.73470322400004], [-122.41923160399995, 37.73557549000003], [-122.41822247899995, 37.73557549000003], [-122.41822247899995, 37.73470322400004]]]}, "attributes": {"grid_code": 1, "Id": 1, "OBJECTID": 1, "Shape_Area": 8.802254272339275e-07, "Shape_Length": 0.0037627819999670464}}, {"geometry": {"rings": [[[-122.39803999299994, 37.72598022400007], [-122.39904911699995, 37.72598022400007], [-122.39904911699995, 37.726852552000025], [-122.40005824099995, 37.726852552000025], [-122.40005824099995, 37.727724874000046], [-122.40106736599995, 37.727724874000046], [-122.40106736599995, 37.731214098000066], [-122.40207648999996, 37.731214098000066], [-122.40207648999996, 37.73295867400003], [-122.40308561399996, 37.73295867400003], [-122.40308561399996, 37.736447750000025], [-122.40106736599995, 37.736447750000025], [-122.40106736599995, 37.73557549000003], [-122.39904911699995, 37.73557549000003], [-122.39904911699995, 37.73470322400004], [-122.39299437099999, 37.73470322400004], [-122.39299437099999, 37.73295867400003], [-122.39400349499999, 37.73295867400003], [-122.39400349499