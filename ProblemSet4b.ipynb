# %% [markdown]
# # Problem Set 4b
# Here you will mimic the steps provided in the `02-Get-Census-Data.ipynb` notebook to extract a set of features from an ArcGIS Onlne Dataset.
# * Work independently on this project.
# * If anything is unclear, please ask for clarification
# * You are encouraged to consult the online documentation for the [ArcGIS Python API](https://developers.arcgis.com/python/), in particular, the sections on [Accessing/creating content](https://developers.arcgis.com/python/guide/accessing-and-creating-content/), [Items](https://esri.github.io/arcgis-python-api/apidoc/html/arcgis.gis.toc.html#item), [Feature Layers](https://esri.github.io/arcgis-python-api/apidoc/html/arcgis.features.toc.html#featurelayer), and [Feature Sets](https://esri.github.io/arcgis-python-api/apidoc/html/arcgis.features.toc.html#featureset).
# * When complete, rename the Juypter notebook to include your NetID, e.g. `PS4b_user123.ipynb`, and upload to Sakai.

# %% [markdown]
# ---
# 1. Import the arcgis GIS object and authenticate the session using your ArcGIS Pro application. Also import Pandas (`import pandas as pd`)
# 1. Use the API's content helper to search for feature layer data using the keywords "`NCOneMap environment`"
#     1. Show a list of the results returned (you should get 3).
# 1. Save the result with "owner:NCDOT.GOV" to a variable named `myItem`.
# 1. Display the layer(s) associated with this item
# 1. Save the first layer associated with this to a variable named `myLayer`
# 1. Print the URL associated with this layer
#     1. Open this url in your browser. If you get the error "SSL required" change the beginning of the url from "`http://`" to "`https://`"
# 1. Create a dataframe and view the attributes *(Code provided here)*
# 1. Show the first few records in the table *(Code provided here)*
# 1. Reveal all unique values in the "RECEIVING_" column *(Code provided here)*
# 1. Query records where RECEIVING_ = 'South Fork Catawba River' into a variable called `myFeatureSet`
# 1. Save the selected features to a shapefile called `SFC_NPDES` in your `V:/` drive

# %%
# 1. Import packages and authenticate your GIS
import pandas as pd

# %%
# 2. Search gis content ofr NCOneMap "environment" feature layers

# %%
# 2A.Show a list of the results returned
# Out:
# [<Item title:"NC1Map NPDES" type:Feature Layer Collection owner:NCDOT.GOV>,
#  <Item title:"swlg" type:Feature Layer Collection owner:amandahenley1>,
#  <Item title:"State Owned_5_1_2018" type:Feature Layer Collection owner:jessica.knight>]

# %%
#3. Save the result with "owner:NCDOT.GOV" to a variable named myItem
myItem =

# %%
#4. Display the layer(s) associated with this item
# Out:
# [<FeatureLayer url:"https://services.arcgis.com/ycIuRaoIC4UuCDAS/arcgis/rest/services/swlg/FeatureServer/0">]

# %%
#5. Save the first layer item a variable named myLayer
myLayer =

# %% [markdown]
# ***If you have had any issues getting the feature layer to this point, run the following code cell to access it directly***<br>You can then proceed with the remainder of the exercise...

# %%
#Run this only if you've been unsuccessful above
from arcgis.features import FeatureLayer
lyr_url = 'https://services.nconemap.gov/secure/rest/services/NC1Map_Environment/MapServer/4'
myLayer = FeatureLayer(lyr_url)

# %%
#6. Print the URL associated with this layer
print()
# Out:
# https://services.nconemap.gov/secure/rest/services/NC1Map_Environment/MapServer/4

# %%
#7. Create a dataframe and view the attributes This takes a moment
df = myLayer.query().sdf

# %%
#8. Show the first few records in the table
df.head(2)
# Out:
#    ANGLE  CLASS        COUNTY      DDLAT     DDLONG  \
# 0      1  Minor          Ashe  36.478333 -81.505833
# 1      1  Major  Transylvania  35.250833 -82.692778
#
#                          FACILITY  LATITUDE  LONGITUDE  NPDES0306_  \
# 0  United Chemi-Con Manufacturing  36284200  -81302100           0
# 1   RFS Ecusta, Inc. ( 1 Ecusta )  35150300  -82413400           0
#
#    NPDES0306_ID             ...                 PERMIT POLYGONID  \
# 0             0             ...              NC0000019         0
# 1             0             ...              NC0000078         0
#
#              RECEIVING_         REGION  SCALE  \
# 0  North Fork New River  Winston-Salem      1
# 1    FRENCH BROAD RIVER      Asheville      1
#
#                                                SHAPE SUBBASIN  \
# 0  {"x": 385039.2810315958, "y": 305513.906153466...    50702
# 1  {"x": 273646.56207985315, "y": 172736.70231780...    40301
#
#                               TYPE UT_  onemap.SDEADMIN.npdes.AREA
# 0  Industrial Process & Commercial  no                           0
# 1  Industrial Process & Commercial  no                           0
#
# [2 rows x 23 columns]

# %%
#9. Reveal all unique values in the "RECEIVING_" column
df['RECEIVING_'].unique()
# Out:
# array(['North Fork New River', 'FRENCH BROAD RIVER', 'Galloway Creek',
#        'North Toe River', 'Tuckasegee River', 'PIGEON RIVER',
#        'West Fork French Broad River', 'Little River (Cascade Lake)',
#        'Lake Julian', 'DEEP RIVER (Randleman Lake)', 'CAPE FEAR RIVER',
#        'ROANOKE RIVER', 'Taylor Creek', 'Far Creek',
#        'East Fork Deep River', 'HAW RIVER', 'Parker Creek',
#        'Barlow Branch', 'Banks Channel', 'Northeast Cape Fear River',
#        'NEUSE RIVER', 'Buttermilk Creek', 'Little Cokey Swamp',
#        'Beech Branch', 'TAR RIVER', 'DAN RIVER', 'Roanoke Sound',
#        'Panther Creek', 'Bay River', 'Conaby Creek', 'CHOWAN RIVER',
#        'Brinson Creek', 'Grove Creek', 'Lick Fork Creek', 'Taylors Creek',
#        'Southwest Prong Slocum Creek', 'Pantego Creek', 'Dicks Branch',
#        'Marlowe Creek', 'Raccoon Creek', 'PAMLICO RIVER',
#        'Rock Fish Creek (New Kirk Pond)', 'North Flat River',
#        'Livingston Creek (Broadwater Lake)',
#        'South Hyco Creek (Lake Roxboro)',
#        'Hyco River, including Hyco Lake below elevation 410',
#        'Little Dan River', 'DAN RIVER (North Carolina portion)',
#        'Voss Creek (Sandy Branch)', 'Mill Creek (at Selma)',
#        'Horsepen Creek', 'Spring Branch',
#        'Little River (Lower Little River)', 'Muddy Creek', 'South Creek',
#        'First Broad River', 'North Fork Catawba River', 'Crowders Creek',
#        'YADKIN RIVER (including Falls Lake below normal operating levels)',
#        'CATAWBA RIVER (Lake Wylie below elevation 570)',
#        'North Pacolet River', 'Second Broad River', 'South Branch',
#        'LUMBER RIVER', 'North Potts Creek (Second Potts Creek)',
#        'Brushy Creek', 'Paw Creek',
#        'YADKIN RIVER (including upper portion of High Rock Lake below normal operating level)',
#        'South Fork Catawba River', 'Long Creek', 'Rocky Creek',
#        'Second Creek (North Second Creek)', 'Buffalo Creek',
#        'CATAWBA RIVER (Mountain Island Lake below elevation 648)',
#        'CATAWBA RIVER (Lake Norman below elevation 760)',
#        'Beaverdam Creek', 'BROAD RIVER', 'Hunting Creek',
#        'Abernethy Creek', 'Silver Creek', 'YADKIN RIVER',
#        'Gum Swamp Creek (Lytchs Pond)', 'Juniper Creek',
#        'Clark Creek (Shooks Lake)', 'Irish Buffalo Creek', 'Rocky River',
#        'Fisher River', 'White Marsh', 'Lake Waccamaw', 'Atlantic Ocean',
#        'Fullers Creek', 'Smith Creek', 'Contentnea Creek',
#        'Pembroke Creek', 'Gideon Creek', 'Ledge Creek',
#        'Dismal Swamp Canal', 'Mauney Creek',
#        'Big Marsh Swamp (Marsh Swamp) (Lake McNeill, Odom Pond)',
#        'Williams Old Mill Branch (Mill Branch)', 'Scott Creek',
#        'Cane River', 'North Deep Creek', 'Millers Creek', 'Robeson Creek',
#        'Hannah Creek', 'CATAWBA RIVER (Lake Hickory below elevation 935)',
#        'PEE DEE RIVER', 'Town Creek', 'Scuppernong River',
#        'Little Buffalo Creek', 'Looking Glass Creek', 'Bent Creek',
#        'North Fork Mills River',
#        'Nutbush Creek (Including Nutbush Creek Arm of John H. Kerr Reservoir below normal pool elevation)',
#        'Third Creek (Third Creek WS No. 37)', 'South Fork New River',
#        'Shoe Heel Creek (Big Shoe Heel Creek)(Maxton Pond)',
#        'Catheys Creek', 'Valley River', 'Fishing Creek',
#        'Tanyard Creek (Buck Creek)', 'HIWASSEE RIVER',
#        'PEE DEE RIVER (including Blewett Falls Lake below normal operating levels)',
#        'Burgaw Creek', 'Ararat River',
#        'HIWASSEE RIVER (Chatuge Lake below elevation 1928)',
#        'Curtis Creek', 'East Prong Slocum Creek', 'Cody Creek',
#        'Intracoastal Waterway', 'Trent River', 'Whiteoak Creek',
#        'Cullasaja River', 'Moadams Creek (Latham Lake)',
#        'WHITE OAK RIVER', 'Dutchman Creek', 'Hickory Branch',
#        'LITTLE TENNESSEE RIVER (Including  backwaters of Fontana Lake at normal pool elevation 1708 feet MSL)',
#        'NEWPORT RIVER', 'Sandyberry Creek',
#        'Vaughn Creek (North Carolina Portion)', 'Brown Marsh Swamp',
#        'Mosely Creek', 'Little Shoe Heel Creek', 'Naked Creek',
#        'Toms Branch', 'Perquimans River',
#        'Soules Swamp (Benson Millpond)', 'Mayo River', 'Bogue Swamp',
#        'Gunpowder Creek', 'Stewarts Creek', 'Gum Branch',
#        'Little Alamance Creek (Guilford County)', 'Long Branch',
#        'Middle Creek', 'Sally Branch', 'Mott Creek', 'Reed Creek',
#        'Reedy Fork', 'Grassy Gap Creek (Grassy Gap Branch)',
#        'Linville River', 'Avery Creek (Dubose Lake)', 'Flattop Creek',
#        'Trays Island Creek',
#        'HIWASSEE RIVER (Apalachia Lake below elevation 1281)',
#        'LITTLE TENNESSEE RIVER (Cheoah Lake, Calderwood Lake)',
#        'Cashie River', 'Squires Run', 'Polecat Creek', 'Canal Creek',
#        'Colly Creek', 'Fites Creek', 'Little Crabtree Creek',
#        'Flat Swamp Creek', 'Carpenter Creek', 'Little Northeast Creek',
#        'Ellerbe Creek', 'Big Alamance Creek (Alamance Creek)',
#        'Lower Creek', 'Hamby Creek', 'DEEP RIVER', 'Chockoytte Creek',
#        'Richland Creek', 'Rich Fork', 'Lyle Creek', 'McLin Creek',
#        'North Buffalo Creek', 'Richardson Creek', 'Toxaway Creek',
#        'West Belews Creek (Little Belews Creek)',
#        'Little Mud Creek (Kanuga Lake, Wolf Lake)', 'Bakers Swamp',
#        'Six Runs Creek', 'South Yadkin River', 'Little Sugar Creek',
#        'Irwin Creek', 'McAlpine Creek (Waverly Lake)', 'Pasquotank River',
#        'Oconaluftee River', 'Morgan Creek', 'McKee Creek', 'Buzzard Bay',
#        'Bridgers Creek', 'Cane Creek', 'Town Fork Creek', 'Mud Creek',
#        'Great Coharie Creek (Blackmans Pond)', 'Little Raft Swamp',
#        'Butterwood Creek', 'King Creek Restricted Area (Spicer Bay)',
#        'Cleghorn Creek', 'George Branch', 'Grissett Swamp',
#        'Persimmon Branch', 'Flat Swamp', 'Northeast Creek',
#        'Haskett Creek', 'Lower Little River', 'Bryant Swamp', 'Eno River',
#        'Loves Creek', 'Battalina Creek', 'Rockfish Creek',
#        'CATAWBA RIVER (including backwaters of Rhodhiss Lake below elevation 995)',
#        'Calico Creek', 'Mill Timber Creek', 'Little River', 'Lick Creek',
#        'HIWASSEE RIVER (Mission Reservoir)',
#        'Little Coharie Creek (Sinclair Lake)', 'Knap of Reeds Creek',
#        'Dunns Marsh (Hughes Mill Pond)', 'Southport Restricted Area',
#        'Middle Fork South Fork New River', 'Grants Creek',
#        'Three Quarter Creek', 'Abbotts Creek', 'Kenneth Creek',
#        'Waxhaw Creek', 'Camel Branch', 'Rocky Branch',
#        'Brushy Fork Creek', 'Salters Creek', 'Densons Creek',
#        'Setman Branch', 'Joels Creek', 'Irvins Creek (McEwen Lake)',
#        'Naked Run', 'High Rock Lake',
#        'Second Creek Arm of High Rock Lake', 'Pott Creek',
#        'Little Contentnea Creek', 'Harmon Creek', 'Logan Creek',
#        'Fifth Creek (Five Mile Branch)', 'Flat Shoals Creek',
#        'North Muddy Creek', 'Dix Creek',
#        'South Potts Creek (First Potts Creek)', 'Dry Creek',
#        'Country Line Creek', 'Mallard Creek', 'Hyatt Creek', 'Bell Swamp',
#        'WATAUGA RIVER', 'Little Creek', 'Stafford Creek',
#        'Southwest Creek', 'Dog Creek', 'Buchanan Creek', 'Grassy Creek',
#        'Jumping Run Creek', 'Swift Creek', 'Fourth Creek',
#        'Youngs Fork (Coperning Creek)', 'Main Canal',
#        'Elk River (Mill Pond)', 'Cherry Creek', 'Brushy Fork',
#        'Lance Creek', 'Southwest Creek (Kellys Pond)',
#        'Wheat Swamp Creek', 'Belch Branch', 'Mull Creek',
#        'Rockyhock Creek (Bennett Millpond)', 'Duharts Creek', 'Big Creek',
#        'Blanton Branch', 'Dixon Branch', 'Kings Creek',
#        'South Fork Mills River', 'Little Long Creek', 'Henderson Creek',
#        'Valley Creek', 'Little Whiteoak Creek',
#        'Bennetts Creek (Merchants Millpond)',
#        'Raynor Swamp (Hunters Millpond)', 'Shelton Laurel Creek',
#        'Coles Cove Branch', 'Hicks Run (Hickory Run)', 'Reedy Creek',
#        'Terrapin Creek', 'Goose Creek', 'Fries Creek', 'Muddy Fork',
#        'Withrow Creek', 'North Fork Crooked Creek',
#        'Unnamed Tributary to Watauga River', 'South Muddy Creek',
#        'Upper Little River', 'Thompson Branch',
#        'Mill Creek (Including Mill Creek Arm of John H. Kerr Reservoir below normal pool elevation)',
#        'Croatan Sound', 'Swanquarter Bay', 'Lower Beaverdam Creek',
#        'Swannanoa River', 'Mountain Creek', 'Cove Branch', 'Foster Creek',
#        'NEW RIVER', 'McDowell Creek', 'West Fork Deep River',
#        'Knobbs Creek', 'South Hyco Creek', 'Pounder Fork', 'Byers Creek',
#        'Rocky Run', 'Wesley Creek (Bent Creek Ranch Lake)', 'Big Branch',
#        'Bills Branch (Bili Branch)', 'Jacob Fork', 'Huffines Mill Creek',
#        'Allen Branch', 'Sawyers Creek', 'Turkey Swamp',
#        'Belews Creek (including Belews Lake below elevation 725) (1)',
#        'Patterson Creek', 'Aberdeen Creek', 'Brooks Creek',
#        'Nantahala River [Nantahala Lake (Aquone Lake)]',
#        'Salem Creek (Middle Fork Muddy Creek)', 'Stony Creek',
#        'Toisnot Swamp (Silver Lake, Lake Wilson)', 'Laurel Fork',
#        'Hickory Creek', 'North Prong Stinking Quarter Creek',
#        'South Buffalo Creek', 'Brush Creek', 'Mayo Creek (Maho Creek)',
#        'Little Fishing Creek', 'Burnt Coat Swamp',
#        'Kehukee Swamp (White Millpond)', 'Deep Creek', 'Trout Creek',
#        'Bear Creek', 'Mitchell River', 'Paint Fork', 'Hominy Creek',
#        'Cedar Creek', 'Flat Creek', 'Buckhorn Creek (Harris Lake)',
#        'Clark Creek', 'Hicks Branch', 'East Fork Pigeon River',
#        'Roses Creek (Tablerock Creek)', 'Henry Fork', 'Caraway Creek',
#        'Fork Creek', 'Mountain Run', 'Indian Creek',
#        'Mill Landing Creek (Mill Creek)', 'Pamlico Sound',
#        'Abbotts Creek Arm of High Rock Lake',
#        'CATAWBA RIVER (Rhodhiss Lake below elevation 995)',
#        'Curl Tail Creek', 'Flat Branch', 'Champ Creek', 'Huffmans Creek',
#        'Jimmys Creek', 'Leonard Creek', 'Crooked Creek', 'Brandy Branch',
#        'Collins Creek', 'Draft Branch', 'Cypress Creek', 'Swearing Creek',
#        'New Hope Creek', 'Cub Creek', 'Scott Creek (Steadmans Creek)',
#        'Hitchcock Creek (Roberdel Lake)', 'Bush Creek', 'New Begun Creek',
#        'Gum Swamp Run', 'Lindscomb Branch', 'Pretty Creek',
#        'Cole Creek (Lilleys Millpond)', 'Little Fisher River',
#        'Norris Branch', 'Dutch Buffalo Creek', 'Hogans Creek',
#        'Bogue Sound (Including Intracoastal Waterway to Beaufort Inlet)',
#        'Persimmon Swamp', 'Little Neatman Creek', 'Bolivia Branch',
#        'Bear Branch', 'Back Creek', 'Duck Creek', 'Little Brier Creek',
#        'Troublesome Creek (Lake Reidsville)', 'Troublesome Creek',
#        'Hughes Branch', 'Mulberry Creek', 'Little Sandy Creek',
#        'Dye Creek (Branch)', 'Benaja Creek', 'North Fork Tar River',
#        'Marks Creek (Boyds Lake, City Lake, Everetts Lake)', 'Nelson Bay',
#        'Crabtree Creek (Crabtree Lake)', 'White Oak Creek (Austin Pond)',
#        'Allen Creek', 'Shoe Heel Creek', 'Upper Barton Creek',
#        'Toisnot Swamp', 'Johns River', 'Moccasin Creek',
#        'Bynums Mill Creek', 'Calebs Creek', 'Little Cub Creek',
#        'Poplar Creek', 'Mill Creek', 'Saltrock Branch', 'Wallace Creek',
#        'Leak Creek', 'Battle Run Creek', 'Fuda Creek', 'Cuddybum Creek',
#        'Prince George Creek', 'TOXAWAY RIVER', 'Buckhorn Creek',
#        'Snows Cut', 'Nix Creek (Nicks Creek)', 'Travis Creek',
#        'Lamb Creek (Simpson Lake)', 'Moravian Creek (Yellow Jacket Lake)',
#        'Hunts Branch', 'Spencer Creek', 'Jonathans Creek', 'Reedy Branch',
#        'Blue Creek', 'Beetree Creek', 'Gabriel Creek', 'Hood Creek',
#        'Timmons Creek', 'Hodges Mill Creek', 'Cotton Creek',
#        'Horse Creek', 'Hagan Fork', 'South River',
#        'Hurricane Creek (Hurricane Lake)', 'Daniels Creek',
#        'Horsepasture River (Lupton Lake, Sapphire Lake)', 'James Creek',
#        'Cullasaja River (Ravenel Lake)', 'Camp Creek',
#        'Little Troublesome Creek', 'Smith Mill Creek',
#        'Swift Creek (Lake Wheeler)',
#        'Norton Branch (East side of Little Tennessee River)',
#        'Abes Creek', 'Stanfield Branch', 'Conetoe Creek',
#        'Little Crane Creek (White Oak Creek)', 'East Fork Overflow Creek',
#        'McGill Branch', 'West Fork Linville River', 'Hicks Creek',
#        'Silver Run Creek', 'Pond Branch', 'Mills River', 'Utley Creek',
#        'CHATTOOGA RIVER (Cashiers Lake)', 'Stevens Creek',
#        'Lower Barton Creek', 'Great Branch (Hussey Pond)',
#        'Blanket Creek', 'Toms Creek (Mill Creek)', 'Sugar Branch',
#        'Austin Creek (Mitchell Pond)', 'Buffalo Creek (Wendell Lake)',
#        'Beddingfield Creek', 'Norton Mill Creek', 'Jackeys Creek',
#        'Mitchell Creek', 'Little Black Creek',
#        'Harris Creek (Peeples Creek) (Wake Crossroads Lake)',
#        'Evans Branch', 'Big Horse Creek', 'Quankey Creek',
#        'Beaverdam Branch', 'Crooked Run Creek', 'Terrible Creek',
#        'Mill Pond Creek', 'Cranberry Branch', 'Sluder Branch',
#        'Cove Creek', 'Laxon Creek', 'Dutch Creek', 'East Belews Creek',
#        'Shadrick Creek', 'Shaw Creek', 'Partridge Creek', 'Bird Creek',
#        'Caldwell Creek', 'Whitewater River', 'Lake Mattamuskeet',
#        'Toms Creek', 'Clear Creek', 'Bethel Creek', 'Horsepasture River',
#        'Catawba Creek', 'Blackwood Creek', 'Balls Creek', 'Pungo River',
#        'Pond Creek', 'Dan Holland Creek', 'CATAWBA RIVER', 'Miller Creek',
#        'Rose Bay Creek', 'Coweeta Creek', 'South Deep Creek',
#        'Skyuka Creek', 'Forbush Creek', 'Featherstone Creek',
#        'Sandy Run Creek', 'East Creek', 'Forney Creek', 'Turner Creek',
#        'Pisgah Creek', 'Beaverdam Swamp', 'Devils Fork', 'Ramah Creek',
#        'Dick Branch', 'Dunn Creek', 'Haas Creek', 'McCoy Creek',
#        'Old Field Creek', 'Sandy Creek', 'Little Mountain Creek',
#        'Shallotte River', 'Ader Creek', 'Rock Creek', 'Bachelor Creek',
#        'Fish Dam Creek (Fishtrap Creek)', 'Pole Creek', 'Warrior Creek',
#        'Brunswick River', 'Line Creek',
#        'YADKIN RIVER (including lower portion of High Rock Lake, Tuckertown Lake, Badin Lake)',
#        'Grassy Camp Creek', 'Wolf Branch', 'Uwharrie River',
#        'Wolf Laurel Branch', 'Gray Ditch', 'Cline Creek',
#        'Whispering Pines Lake', 'East Prong Sanders Cr.',
#        'Crozier Branch', 'Cedar Bay',
#        'Newport River Restricted Area (Morehead City Harbor)',
#        'Adams Creek', 'Pungo Lake Canal', 'Belews Creek', 'Hancock Creek',
#        'Laurel Branch (Laurel Creek)', 'Carroll Creek (Lake Hazel)',
#        'Green River', 'Rough Fork', 'Shallowbag Bay', 'Snowbird Creek',
#        'Webbs Creek', 'Little Elk Creek', 'Taggart Creek (Taggard Creek)',
#        'West Branch Rocky River', 'Mauls Swamp', 'Hoyle Creek',
#        'Clarks Creek', 'Killian Creek', 'Morgan Mill Creek (Kaiser Lake)',
#        'Purgatory Branch', 'Marks Creek (Lake Myra)', 'White Oak Creek',
#        'Hominy Swamp', 'Honeycutt Creek', 'Beaver Creek', 'Martin Creek',
#        'Bogue Sound (Including Intracoastal Waterway)',
#        'Anderson Swamp Creek (Including Anderson Swamp Creek Arm of John H. Kerr Reservoir below normal pool elevation)',
#        'Coddle Creek', 'Mingo Swamp', 'Reems Creek', 'Maple Branch',
#        'Reddies River', 'Queen Creek', 'Stones Creek', 'Barnards Creek',
#        'Laurel Creek', 'Basal Creek [(Bass Lake, (Mills Pond)]',
#        'Rock Hole Branch', 'Coffey Creek', 'Blackmar Gut', 'Fryes Creek',
#        'Unnamed Tributary at Camp New Hope (Camp New Hope Lake)',
#        'Chadwick Bay', 'Conley Creek (Connelly Creek)', 'Brier Creek',
#        'Brier Creek Reservoir', 'Sycamore Creek', "Haley's Creek",
#        'Stewart Creek', 'Sevenmile Creek', 'Rocky Creek (Rocky River)',
#        'Ivy Creek (River)', 'Britten Creek', 'Twelvemile Creek',
#        'Crooked Run', 'Bald Head Island Marina Basin',
#        'Big Beaver Island Creek', 'Little Marsh Swamp', 'Raft Swamp',
#        'Stingy Branch', 'Camp Branch (Bailey Branch)', 'Lewis Creek',
#        'Gashes Creek (Cedar Mountain Lake)', 'Crabtree Creek',
#        'Ore Bank Branch', 'Peter Weaver Creek',
#        'Ahoskie Creek (Ahoskie Swamp, Bear Swamp)',
#        'Unnamed Tributary at Guilford College', 'Poplin Branch',
#        'Rowans Branch (Chestnut Pond)', 'Jacobs Creek', 'Steele Creek',
#        'Bashavia Creek', 'Third Fork Creek', 'First Swamp', 'Bull Bay',
#        'Stumpy Point Bay', 'Horsepen Branch', 'Great Swamp',
#        'Feltons Creek', 'Hyco Creek (North Hyco Creek)',
#        'Little Jacob Swamp', 'ALBEMARLE SOUND', 'Chocowinity Bay',
#        'CATAWBA RIVER (including backwaters of Lake James below elevation 1200)',
#        'Riders Creek (First Creek) and connecting canals',
#        'South Fork Big Willow Creek', 'Big Laurel Creek', 'Turkey Creek',
#        'South Toe River', 'Rittle Fork', 'Livingston Creek',
#        'Thunderhole Creek', 'Eurins Creek', 'Juniper Branch',
#        'Rhodes Creek'], dtype=object)

# %%
#10. Query records where RECEIVING_ = 'South Fork Catawba River' into a variable called 'myFeatureSet'
myFeatureSet =

# %%
# 11. Save the selected features to a shapefile called "SFC_NPDES" in your V:/ drive
# Out:
# 'V:\\SFC_NPDES.shp'
