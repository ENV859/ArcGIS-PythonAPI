# %%
#import
from arcgis.gis import GIS

# %%
gis = GIS()
gis.properties.portalName
# Out:
# 'ArcGIS Online'

# %%
gis = GIS('pro')
gis.properties.user.username
# Out:
# 'jpfay_dukeuniv'

# %%
#Get NLCD 2011
lc_item = gis.content.get('b6b0caecc08540eba21211f844174e66')
lc_item
# Out:
# <Item title:"USA NLCD Land Cover 2011" type:Imagery Layer owner:esri>

# %%
lc_item.layers
# Out:
# [<ImageryLayer url:"https://landscape10.arcgis.com/arcgis/rest/services/USA_NLCD_Land_Cover_2011/ImageServer">]

# %%
lc_lyr = lc_item.layers[0]
lc_lyr
# Out:
# <ImageryLayer url:"https://landscape10.arcgis.com/arcgis/rest/services/USA_NLCD_Land_Cover_2011/ImageServer">

# %%
lc_lyr.properties.capabilities
# Out:
# 'Catalog,Image,Metadata'

# %%
for rasterfunc in lc_lyr.properties.rasterFunctionInfos:
    print(rasterfunc.name)
# Out:
# None

# %%
m.add_layer(lc_lyr)
